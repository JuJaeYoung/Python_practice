# %%
import networkx as nx
G = nx.Graph()

# %%
G.add_node(1)
print(G.nodes())
# Out:
# [1]

# %%
G.add_node('P')
G.add_node('Hi')
print(G.nodes())
# Out:
# [1, 'P', 'Hi']

# %%
G.add_nodes_from([2,3])
print(G.nodes())
# Out:
# [1, 'P', 'Hi', 2, 3]

# %%
G.add_nodes_from([3,4])
print(G.nodes())
# Out:
# [1, 'P', 'Hi', 2, 3, 4]

# %%
G.add_edge(1,1)
G.add_edge(2,2)
G.add_edge(1,2)
G.add_edge(4,5)
G.add_edges_from([(1,2),(1,3),(1,4),(1,5)])
G.add_edges_from([(1,'Hi'),(1,'P')])
nx.draw(G, with_labels=True, node_color='yellow', edge_color='red')

# %%
import networkx as nx
G = nx.path_graph(4)
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='gray')

# %%
import networkx as nx
G = nx.Graph()
nx.add_path(G, [0,1,2,3])

# %%
print(G.degree(0))
print(G.degree([0,1]))
print(G.degree())
# Out:
# 1
# [(0, 1), (1, 2)]
# [(0, 1), (1, 2), (2, 2), (3, 1)]

# %%
print(G.edges())
G.remove_edge(1,2)
print(G.edges())
# Out:
# [(0, 1), (1, 2), (2, 3)]
# [(0, 1), (2, 3)]

# %%
print(G.edges())
G.remove_edges_from([(0,1),(2,3)])
print(G.edges())
# Out:
# [(0, 1), (2, 3)]
# []

# %%
print(G.nodes())
G.remove_node(2)
print(G.nodes())
# Out:
# [0, 1, 2, 3]
# [0, 1, 3]

# %%
print(G.nodes())
G.remove_nodes_from([0,1,3])
print(G.nodes())
# Out:
# [0, 1, 3]
# []

# %%
import networkx as nx
G = nx.Graph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(1,4),(1,5),(4,5)])
print(G.number_of_nodes())
print(G.number_of_edges())
# Out:
# 5
# 5

# %%
G.remove_edge(1,3)
print(G.number_of_nodes())
print(G.number_of_edges())
# Out:
# 5
# 4

# %%
import networkx as nx
G = nx.Graph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(1,4),(1,5),(4,5)])
G.remove_edge(1,3)
print(G.number_of_nodes())
print(G.number_of_edges())
# Out:
# 5
# 4

# %%
nx.draw(G, with_labels=True)

# %%
import networkx as nx
G = nx.Graph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(1,4),(1,5),(4,5)])
G.remove_node(4)
print(G.number_of_nodes())
print(G.number_of_edges())
# Out:
# 4
# 3

# %%
import networkx as nx
G = nx.Graph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(1,4),(1,5),(4,5)])
G.remove_nodes_from([4,5])
print(G.number_of_nodes())
print(G.number_of_edges())
# Out:
# 3
# 2

# %%
G = nx.Graph()
G.add_edge('a', 'b', weight=3)
G.add_edge('b', 'c', weight=4)
G.add_edge('c', 'd', weight=3)
G.add_edge('d', 'b', weight=8)
G.add_edge('c', 'a', weight=10)
labels=nx.get_edge_attributes(G, 'weight')
print(labels)
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='grey')
# Out:
# {('a', 'b'): 3, ('a', 'c'): 10, ('b', 'c'): 4, ('b', 'd'): 8, ('c', 'd'): 3}

# %%
nx.shortest_path(G, 'a', 'd', weight='weight')
# Out:
# ['a', 'b', 'c', 'd']

# %%
G = nx.Graph()
G.add_edge('a', 'b', weight=4)
G.add_edge('a', 'd', weight=8)
G.add_edge('b', 'd', weight=3)
G.add_edge('b', 'e', weight=10)
G.add_edge('f', 'd', weight=12)
G.add_edge('f', 'e', weight=7)
labels = nx.get_edge_attributes(G, 'weight')
print(labels)
nx.shortest_path(G, 'a', 'f', weight='weight')
nx.draw(G, with_labels=True)
# Out:
# {('a', 'b'): 4, ('a', 'd'): 8, ('b', 'd'): 3, ('b', 'e'): 10, ('d', 'f'): 12, ('e', 'f'): 7}

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.erdos_renyi_graph(25, 0.2)
nx.draw(G)

# %%
G = nx.watts_strogatz_graph(30, 3, 0.1)
nx.draw(G)

# %%
G = nx.barabasi_albert_graph(25, 5)
nx.draw(G)

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.stats import bernoulli
def erdosGraph(N, p):
    G = nx.Graph()
    G.add_nodes_from(range(N))              # 0 ~ N-1 노드 생성
    listG = list(G.nodes())                 # 노드 리스트
    for i, node1 in enumerate(listG):      # 인덱스와 노드 값 반환 
        for node2 in listG[i+1:]:
            if (bernoulli.rvs(p=p)):       # 1이 나오면 실행
                G.add_edge(node1, node2)
    return G
nx.draw(erdosGraph(20, 0.18))

# %%
# erdos_renyi의 확률적인 히스토그램을 그려보자
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.stats import bernoulli
def erdosGraph(N, p):
    G = nx.Graph()
    G.add_nodes_from(range(N))              
    listG = list(G.nodes())                 
    for i, node1 in enumerate(listG):       
        for node2 in listG[i+1:]:
            if (bernoulli.rvs(p=p)):       
                G.add_edge(node1, node2)
    return G
G1 = erdosGraph(80, 0.3)
plt.hist(list([d for n, d in G1.degree()]), histtype='step')
# Out:
# (array([ 3.,  5.,  7.,  8., 14., 12., 14.,  9.,  7.,  1.]),
#  array([14. , 15.8, 17.6, 19.4, 21.2, 23. , 24.8, 26.6, 28.4, 30.2, 32. ]),
#  [<matplotlib.patches.Polygon at 0x1610d5675b0>])

# %%
# 같은 노드의 개수와 같은 확률로 엣지를 만드는 erdos_renyi의 그래프를 3번 반복해보자
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.stats import bernoulli
def erdosGraph(N, p):
    G = nx.Graph()
    G.add_nodes_from(range(N))              
    listG = list(G.nodes())                 
    for i, node1 in enumerate(listG):       
        for node2 in listG[i+1:]:
            if (bernoulli.rvs(p=p)):       
                G.add_edge(node1, node2)
    return G
def pltGraph(G):
    plt.hist(list([d for n, d in G.degree()]), histtype='step')
G1 = erdosGraph(80, 0.3)
pltGraph(G1)
G2 = erdosGraph(80, 0.3)
pltGraph(G2)
G3 = erdosGraph(80, 0.3)
pltGraph(G3)

# %%
# 엑셀 파일로 그래프 생성
import numpy as np
import networkx as nx
K = np.loadtxt("test.csv", delimiter=',')
G = nx.to_networkx_graph(K)
nx.draw(G, with_labels=True)

# %%
import numpy as np
import networkx as nx
K = np.loadtxt("test1.csv", delimiter=',')
G = nx.to_networkx_graph(K)
nx.draw(G, with_labels=True)

# %%
import numpy as np
import networkx as nx
K = np.loadtxt("test2.csv", delimiter=',')
G = nx.to_networkx_graph(K)
nx.draw(G, with_labels=True)

# %%
import networkx as nx
G = nx.karate_club_graph()
import matplotlib.pyplot as plt
nx.draw(G, with_labels=True)
